# %%
import pandas as pd

# %%
df =pd.read_csv('../data/data.csv',usecols=lambda x: x != "id")

# %%
df
# Out:
#             exercise_name   type_of_activity type_of_equipment   body_part  \
# 0                Push-Ups           Strength        Bodyweight  Upper Body
# 1                  Squats           Strength        Bodyweight  Lower Body
# 2                   Plank  Strength/Mobility        Bodyweight        Core
# 3                Deadlift           Strength           Barbell  Lower Body
# 4             Bicep Curls           Strength         Dumbbells  Upper Body
# ..                    ...                ...               ...         ...
# 202  Incline Dumbbell Row           Strength         Dumbbells  Upper Body
# 203  Machine Lat Pulldown           Strength           Machine  Upper Body
# 204     One-Arm Cable Row           Strength     Cable Machine  Upper Body
# 205             Face Pull           Strength     Cable Machine  Upper Body
# 206  Dumbbell Bench Press           Strength         Dumbbells  Upper Body
#
#      type                 muscle_groups_activated  \
# ...
